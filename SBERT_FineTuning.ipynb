# %% [markdown]
# # 📚 SBERT Fine-Tuning on Mental Health Books (VSCode Version)
#
# This notebook fine-tunes **SBERT (Sentence-BERT)** on each book in the mental health dataset, and plots the **training loss vs. epochs**.
#
# ✅ Directly loads text files from the local folder `./sbert_books_data`
# ✅ Fine-tunes SBERT on each book
# ✅ Plots loss graphs
#
# Let's get started! 🚀

# %%
# 🔧 Step 1: Install Required Libraries
! pip install sentence-transformers torch matplotlib
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\vee\anaconda3\lib\site-packages (4.1.0)
# Requirement already satisfied: torch in c:\users\vee\anaconda3\lib\site-packages (2.7.0)
# Requirement already satisfied: matplotlib in c:\users\vee\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\vee\anaconda3\lib\site-packages (from sentence-transformers) (4.52.3)
# Requirement already satisfied: tqdm in c:\users\vee\anaconda3\lib\site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: scikit-learn in c:\users\vee\anaconda3\lib\site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy in c:\users\vee\anaconda3\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\vee\anaconda3\lib\site-packages (from sentence-transformers) (0.32.2)
# Requirement already satisfied: Pillow in c:\users\vee\anaconda3\lib\site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\vee\anaconda3\lib\site-packages (from sentence-transformers) (4.11.0)
# Requirement already satisfied: filelock in c:\users\vee\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\vee\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\vee\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\vee\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\vee\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\vee\anaconda3\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vee\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\vee\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vee\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vee\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\vee\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\vee\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vee\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vee\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\vee\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in c:\users\vee\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: six>=1.5 in c:\users\vee\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\vee\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\vee\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\vee\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\vee\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\vee\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vee\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\vee\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\vee\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vee\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vee\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vee\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vee\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.8.30)

# %% [markdown]
# ### 📂 Step 2: Ensure Book Text Files Are Ready
# Place your extracted `.txt` files from the books in a folder named `./sbert_books_data`. This folder should be in the same directory as this notebook.

# %%
import os
if not os.path.exists('./sbert_books_data'):
    print("❌ Error: './sbert_books_data' folder not found.")
else:
    print("✅ './sbert_books_data' folder found.")
# Out:
# ✅ './sbert_books_data' folder found.

# %%
from sentence_transformers import SentenceTransformer
from torch.utils.data import DataLoader, TensorDataset
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import os

book_dir = './sbert_books_data'
book_files = [f for f in os.listdir(book_dir) if f.endswith('.txt')]

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")

for book_file in book_files:
    print(f"\nFine-tuning SBERT on: {book_file}")
    with open(os.path.join(book_dir, book_file), 'r', encoding='utf-8') as f:
        text = f.read()
    sentences = [s.strip() for s in text.split('\n') if len(s.strip()) > 30]

    if len(sentences) < 2:
        print(f"Skipping {book_file} (not enough data)")
        continue

    model = SentenceTransformer('all-MiniLM-L6-v2').to(device)
    optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5)
    criterion = nn.CosineEmbeddingLoss()
    num_epochs = 3
    batch_size = 4
    loss_values = []

    # Prepare sentence pairs and labels
    pairs = []
    labels = []
    for sentence in sentences:
        pairs.append((sentence, sentence))
        labels.append(1)
        pairs.append((sentence, "Random unrelated sentence."))
        labels.append(-1)  # For CosineEmbeddingLoss: -1 means dissimilar

    num_batches = len(pairs) // batch_size + int(len(pairs) % batch_size != 0)

    for epoch in range(num_epochs):
        model.train()
        total_loss = 0
        for i in range(num_batches):
            batch_pairs = pairs[i*batch_size:(i+1)*batch_size]
            batch_labels = torch.tensor(labels[i*batch_size:(i+1)*batch_size], dtype=torch.float).to(device)

            sentences1 = [p[0] for p in batch_pairs]
            sentences2 = [p[1] for p in batch_pairs]

            # Use model's encode with output_value='token_embeddings' and get_grad for gradient tracking
            embeddings1 = model.encode(sentences1, convert_to_tensor=True, show_progress_bar=False, device=device, output_value='sentence_embedding')
            embeddings2 = model.encode(sentences2, convert_to_tensor=True, show_progress_bar=False, device=device, output_value='sentence_embedding')

            embeddings1.requires_grad = True
            embeddings2.requires_grad = True

            optimizer.zero_grad()
            loss = criterion(embeddings1, embeddings2, batch_labels)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        avg_loss = total_loss / num_batches
        loss_values.append(avg_loss)
        print(f"Epoch {epoch+1}/{num_epochs} - Loss: {avg_loss:.4f}")

    # Plot loss
    plt.figure()
    plt.plot(range(1, num_epochs+1), loss_values, marker='o')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f"Training Loss for {book_file}")
    plt.grid(True)
    plt.show()
# Out:
# Using device: cpu
#
# Fine-tuning SBERT on: A-Dictionary-for-Psychotherapists.txt
# Epoch 1/3 - Loss: 0.0859
# Epoch 2/3 - Loss: 0.0859
# Epoch 3/3 - Loss: 0.0859
# Fine-tuning SBERT on: MentalHealthGuidebookCovid19.txt
# Epoch 1/3 - Loss: 0.0705
# Epoch 2/3 - Loss: 0.0705
# Epoch 3/3 - Loss: 0.0705
# Fine-tuning SBERT on: mental_health_one.txt
# Epoch 1/3 - Loss: 0.0509
# Epoch 2/3 - Loss: 0.0509
# Epoch 3/3 - Loss: 0.0509
# Fine-tuning SBERT on: psychological-disorders.txt
# Epoch 1/3 - Loss: 0.0753
# Epoch 2/3 - Loss: 0.0753
# Epoch 3/3 - Loss: 0.0753
# Fine-tuning SBERT on: survival-kit-major-mental-illnesses-signs-and-syptoms.txt
# Epoch 1/3 - Loss: 0.0867
# Epoch 2/3 - Loss: 0.0867
# Epoch 3/3 - Loss: 0.0867
